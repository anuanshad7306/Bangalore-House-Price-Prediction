# %%
import pandas as pd
df=pd.read_csv("/content/bengaluru_house_prices.csv")
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# 1      4 Bedroom  Theanmp       2600   5.0      3.0  120.00
# 2          3 BHK      NaN       1440   2.0      3.0   62.00
# 3          3 BHK  Soiewre       1521   3.0      1.0   95.00
# 4          2 BHK      NaN       1200   2.0      1.0   51.00
# ...          ...      ...        ...   ...      ...     ...
# 13315  5 Bedroom  ArsiaEx       3453   4.0      0.0  231.00
# 13316      4 BHK      NaN       3600   5.0      NaN  400.00
# 13317      2 BHK  Mahla T       1141   2.0      1.0   60.00
# 13318      4 BHK  SollyCl       4689   4.0      1.0  488.00
# 13319      1 BHK      NaN        550   1.0      1.0   17.00
#
# [13320 rows x 9 columns]

# %% [markdown]
# # underestanding data

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df.tail()
# Out:
#                   area_type   availability               location       size  \
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar      4 BHK
# 13319  Super built-up  Area  Ready To Move           Doddathoguru      1 BHK
#
#        society total_sqft  bath  balcony  price
# 13315  ArsiaEx       3453   4.0      0.0  231.0
# 13316      NaN       3600   5.0      NaN  400.0
# 13317  Mahla T       1141   2.0      1.0   60.0
# 13318  SollyCl       4689   4.0      1.0  488.0
# 13319      NaN        550   1.0      1.0   17.0

# %%
df.sample(3)
# Out:
#                  area_type   availability            location   size  society  \
# 1259  Super built-up  Area  Ready To Move      Sarjapur  Road  2 BHK  Shthi S
# 5378  Super built-up  Area  Ready To Move  5th Phase JP Nagar  2 BHK      NaN
# 4911  Super built-up  Area  Ready To Move            Kadugodi  3 BHK  KMnorab
#
#      total_sqft  bath  balcony  price
# 1259       1035   2.0      1.0   45.0
# 5378       1390   2.0      2.0   65.0
# 4911       1711   3.0      3.0   75.0

# %%
df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
df.describe(include=["object","category"])
# Out:
#                    area_type   availability    location   size  society  \
# count                  13320          13320       13319  13304     7818
# unique                     4             81        1305     31     2688
# top     Super built-up  Area  Ready To Move  Whitefield  2 BHK  GrrvaGr
# freq                    8790          10581         540   5199       80
#
#        total_sqft
# count       13320
# unique       2117
# top          1200
# freq          843

# %%
df.nunique()
# Out:
# area_type          4
# availability      81
# location        1305
# size              31
# society         2688
# total_sqft      2117
# bath              19
# balcony            4
# price           1994
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %%
df.describe(include='all')
# Out:
#                    area_type   availability    location   size  society  \
# count                  13320          13320       13319  13304     7818
# unique                     4             81        1305     31     2688
# top     Super built-up  Area  Ready To Move  Whitefield  2 BHK  GrrvaGr
# freq                    8790          10581         540   5199       80
# mean                     NaN            NaN         NaN    NaN      NaN
# std                      NaN            NaN         NaN    NaN      NaN
# min                      NaN            NaN         NaN    NaN      NaN
# 25%                      NaN            NaN         NaN    NaN      NaN
# 50%                      NaN            NaN         NaN    NaN      NaN
# 75%                      NaN            NaN         NaN    NaN      NaN
# max                      NaN            NaN         NaN    NaN      NaN
#
#        total_sqft          bath       balcony         price
# count       13320  13247.000000  12711.000000  13320.000000
# unique       2117           NaN           NaN           NaN
# top          1200           NaN           NaN           NaN
# freq          843           NaN           NaN           NaN
# mean          NaN      2.692610      1.584376    112.565627
# std           NaN      1.341458      0.817263    148.971674
# min           NaN      1.000000      0.000000      8.000000
# 25%           NaN      2.000000      1.000000     50.000000
# 50%           NaN      2.000000      2.000000     72.000000
# 75%           NaN      3.000000      2.000000    120.000000
# max           NaN     40.000000      3.000000   3600.000000

# %%
df['balcony'].unique()
# Out:
# array([ 1.,  3., nan,  2.,  0.])

# %%
df['balcony'].value_counts()
# Out:
# balcony
# 2.0    5113
# 1.0    4897
# 3.0    1672
# 0.0    1029
# Name: count, dtype: int64

# %%
df1=df.copy()

# %%
df1.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df1.drop(columns=["society"],inplace=True)

# %%
df1['size'].fillna(df1['size'].mode()[0],inplace=True)
# Out:
# <ipython-input-134-c57aab48f5ef>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['size'].fillna(df1['size'].mode()[0],inplace=True)

# %%
df1["location"].fillna(df1['location'].mode()[0],inplace=True)
# Out:
# <ipython-input-135-9744fa70329a>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["location"].fillna(df1['location'].mode()[0],inplace=True)

# %%
import seaborn as sns
sns.histplot(df1['bath'])
# Out:
# <Axes: xlabel='bath', ylabel='Count'>

# %%
df1['bath'].fillna(df1['bath'].median(),inplace=True)
# Out:
# <ipython-input-137-2730037c55a2>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['bath'].fillna(df1['bath'].median(),inplace=True)

# %%
import seaborn as sns
sns.histplot(df1['balcony'])
# Out:
# <Axes: xlabel='balcony', ylabel='Count'>

# %%
sns.kdeplot(df1['balcony'])
# Out:
# <Axes: xlabel='balcony', ylabel='Density'>

# %%
df1['balcony'].fillna(df1['balcony'].mean(),inplace=True)
# Out:
# <ipython-input-140-8a07558b391b>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1['balcony'].fillna(df1['balcony'].mean(),inplace=True)

# %%
df1.duplicated().sum()
# Out:
# 568

# %%
df1.drop_duplicates(inplace=True)

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
print(df.shape)
print(df1.shape)
# Out:
# (13320, 9)
# (12752, 8)

# %%
df1['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
df1['size']=df1['size'].str.extract(r'(\d+\.?\d*)')

# %%
df1['size'].unique()
# Out:
# array(['2', '4', '3', '6', '1', '8', '7', '5', '11', '9', '27', '10',
#        '19', '16', '43', '14', '12', '13', '18'], dtype=object)

# %%
df1['total_sqft']=df1['total_sqft'].str.extract(r'(\d+\.?\d*)')

# %%
df1['total_sqft']=df1['total_sqft'].astype("float")

# %%
df1
# Out:
#                   area_type   availability                  location size  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II    2
# 1                Plot  Area  Ready To Move          Chikka Tirupathi    4
# 2            Built-up  Area  Ready To Move               Uttarahalli    3
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli    3
# 4      Super built-up  Area  Ready To Move                  Kothanur    2
# ...                     ...            ...                       ...  ...
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout    3
# 13315        Built-up  Area  Ready To Move                Whitefield    5
# 13316  Super built-up  Area  Ready To Move             Richards Town    4
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar    2
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar    4
#
#        total_sqft  bath   balcony   price
# 0          1056.0   2.0  1.000000   39.07
# 1          2600.0   5.0  3.000000  120.00
# 2          1440.0   2.0  3.000000   62.00
# 3          1521.0   3.0  1.000000   95.00
# 4          1200.0   2.0  1.000000   51.00
# ...           ...   ...       ...     ...
# 13314      1715.0   3.0  3.000000  112.00
# 13315      3453.0   4.0  0.000000  231.00
# 13316      3600.0   5.0  1.584376  400.00
# 13317      1141.0   2.0  1.000000   60.00
# 13318      4689.0   4.0  1.000000  488.00
#
# [12752 rows x 8 columns]

# %%
df1['size']=df1['size'].str.extract(r'(\d+\.?\d*)')

# %%
df1['size']=df1['size'].astype('int')

# %%
df1
# Out:
#                   area_type   availability                  location  size  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II     2
# 1                Plot  Area  Ready To Move          Chikka Tirupathi     4
# 2            Built-up  Area  Ready To Move               Uttarahalli     3
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli     3
# 4      Super built-up  Area  Ready To Move                  Kothanur     2
# ...                     ...            ...                       ...   ...
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout     3
# 13315        Built-up  Area  Ready To Move                Whitefield     5
# 13316  Super built-up  Area  Ready To Move             Richards Town     4
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar     2
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar     4
#
#        total_sqft  bath   balcony   price
# 0          1056.0   2.0  1.000000   39.07
# 1          2600.0   5.0  3.000000  120.00
# 2          1440.0   2.0  3.000000   62.00
# 3          1521.0   3.0  1.000000   95.00
# 4          1200.0   2.0  1.000000   51.00
# ...           ...   ...       ...     ...
# 13314      1715.0   3.0  3.000000  112.00
# 13315      3453.0   4.0  0.000000  231.00
# 13316      3600.0   5.0  1.584376  400.00
# 13317      1141.0   2.0  1.000000   60.00
# 13318      4689.0   4.0  1.000000  488.00
#
# [12752 rows x 8 columns]

# %%
df1['size']=df1['size'].astype('int')
df1['bath']=df1['bath'].astype('int')
df1['balcony']=df1['balcony'].astype('int')

# %%
df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
df1.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size              int64
# total_sqft      float64
# bath              int64
# balcony           int64
# price           float64
# dtype: object

# %% [markdown]
# #data visualaization

# %%
#set plot style
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style='whitegrid')

#distibution plot for numaric columns
fig,axes=plt.subplots(2,2,figsize=(14,10))

#price distribution
sns.histplot(df1['price'],kde=True,color='blue',ax=axes[0,0])
axes[0,0].set_title('price Distribution')

#total_sqft Distribution
sns.histplot(df1['total_sqft'],kde=True,color='green',ax=axes[0,1])
axes[0,1].set_title('total_sqft Distribution')

#bath distributiuon
sns.histplot(df1['bath'],kde=True,color='red',ax=axes[1,0])
axes[1,0].set_title('bath Distribution')

#balcony distributiuon
sns.histplot(df1['balcony'],kde=True,color='yellow',ax=axes[1,1])
axes[1,1].set_title('balcony Distribution')

plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the plot size for all plots
plt.figure(figsize=(16, 12))

# Bar plot: Average price by area_type
plt.subplot(2, 2, 1)
sns.barplot(x='area_type', y='price', data=df1, palette='Set2')
plt.title('Average price by area_type')
plt.xlabel('Area Type')
plt.ylabel('Average Price')

# Bar plot: Average total sqft by availability status
plt.subplot(2, 2, 2)
sns.barplot(x='area_type', y='total_sqft', data=df1, palette='Set2')
plt.title('Average total sqft by availability status')
plt.xlabel('Area Type')
plt.ylabel('Average Total Sqft')

# Bar plot: Average Bath by availability status
plt.subplot(2, 2, 3)
sns.barplot(x='area_type', y='bath', data=df1, palette='Set2')
plt.title('Average Bath by availability status')
plt.xlabel('Area Type')
plt.ylabel('Average Number of Bathrooms')

# Bar plot: Average Balcony by availability status
plt.subplot(2, 2, 4)  # Changed the subplot index to 4
sns.barplot(x='area_type', y='balcony', data=df1, palette='Set2')
plt.title('Average Balcony by availability status')
plt.xlabel('Area Type')
plt.ylabel('Average Number of Balconies')

# Show the plot
plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()
# Out:
# <ipython-input-158-c4cac6634ac6>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='area_type', y='price', data=df1, palette='Set2')
# <ipython-input-158-c4cac6634ac6>:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='area_type', y='total_sqft', data=df1, palette='Set2')
# <ipython-input-158-c4cac6634ac6>:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='area_type', y='bath', data=df1, palette='Set2')
# <ipython-input-158-c4cac6634ac6>:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='area_type', y='balcony', data=df1, palette='Set2')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#set the plot size for all plots
plt.figure(figsize=(16,12))

#scatter plot:price vs total_sqft
plt.subplot(2,2,1)
sns.scatterplot(x='total_sqft',y='price',data=df1,hue='area_type',palette='Set2',alpha=0.5)
plt.title("total_sqft vs price")
plt.xlabel("number of total_sqft")
plt.ylabel("price")

#scatter plot:bath vs price
plt.subplot(2,2,2)
sns.scatterplot(x='bath',y='price',data=df1,hue='area_type',palette='Set2',alpha=0.5)
plt.title("bath vs price")
plt.xlabel("number of bath")
plt.ylabel("price")


#scatter plot:balcony vs price
plt.subplot(2,2,3)
sns.scatterplot(x='balcony',y='price',data=df1,hue='area_type',palette='Set2',alpha=0.5)
plt.title("balcony vs price")
plt.xlabel("number of balcony")
plt.ylabel("price")

# Show the plot
plt.tight_layout()  # Adjust layout to prevent overlapping labels
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#set the plot size for all plots
plt.figure(figsize=(16,12))

#create a subplot grid for 4 plots (2 rows, 2 columns)
plt.subplot(2,2,1)
sns.boxplot(x="area_type",y='price',data=df1,palette="Set2")
plt.title("price distribution by availablity status")
plt.xlabel("Avalilablity satus")
plt.ylabel("price")


plt.subplot(2,2,2)
sns.boxplot(x="area_type",y='total_sqft',data=df1,palette="viridis")
plt.title("total_sqft distribution by availablity status")
plt.xlabel("Avalilablity satus")
plt.ylabel("total_sqft")


plt.subplot(2,2,3)
sns.boxplot(x="area_type",y='bath',data=df1,palette="Set2")
plt.title("bath distribution by availablity status")
plt.xlabel("Avalilablity satus")
plt.ylabel("bath")



plt.subplot(2,2,4)
sns.boxplot(x="area_type",y='balcony',data=df1,palette="viridis")
plt.title("balcony distribution by availablity status")
plt.xlabel("Avalilablity satus")
plt.ylabel("balcony")

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-160-1eaa83148749>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="area_type",y='price',data=df1,palette="Set2")
# <ipython-input-160-1eaa83148749>:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="area_type",y='total_sqft',data=df1,palette="viridis")
# <ipython-input-160-1eaa83148749>:23: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="area_type",y='bath',data=df1,palette="Set2")
# <ipython-input-160-1eaa83148749>:31: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="area_type",y='balcony',data=df1,palette="viridis")

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='area_type',data=df1, palette="Set1")
plt.title("count properties by area type")
plt.xlabel("area type")
plt.ylabel("count")
plt.xticks(rotation=45)
plt.show()

#location is likely to have many unique values, so we can limit the categories shown
plt.figure(figsize=(12,6))
top_location = df1['location'].value_counts().nlargest(10)#show to 10 locations
sns.countplot(x='location',data=df1[df1["location"].isin(top_location.index)],palette="Set2")
plt.title("coun of properties by location (top 10)")
plt.xlabel('Location')
plt.ylabel('count')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-161-49d838d74174>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='area_type',data=df1, palette="Set1")
# <ipython-input-161-49d838d74174>:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='location',data=df1[df1["location"].isin(top_location.index)],palette="Set2")

# %%
top_location
# Out:
# location
# Whitefield               524
# Sarjapur  Road           379
# Electronic City          286
# Kanakpura Road           242
# Thanisandra              229
# Yelahanka                210
# Marathahalli             169
# Hebbal                   161
# Raja Rajeshwari Nagar    159
# Uttarahalli              154
# Name: count, dtype: int64

# %% [markdown]
# # outer detection and handling

# %%
df2 = df1.copy()
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12752 entries, 0 to 13318
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     12752 non-null  object
#  1   availability  12752 non-null  object
#  2   location      12752 non-null  object
#  3   size          12752 non-null  int64
#  4   total_sqft    12752 non-null  float64
#  5   bath          12752 non-null  int64
#  6   balcony       12752 non-null  int64
#  7   price         12752 non-null  float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 896.6+ KB

# %%
#Define a function  to calculate IQR outliers
def detect_outliers(column):
  q1=column.quantile(0.25)
  q3=column.quantile(0.75)
  iqr=q3-q1
  lower_bound=q1-1.5*iqr
  upper_bound=q3+1.5*iqr
  return(column < lower_bound ) | (column > upper_bound)

# %%
#apply the function to numeric columns
outliers_iqr=df2[['size','total_sqft','bath','balcony','price']].apply(detect_outliers)

# %%
#View outliers
print('outliers detect using outliers')
print(outliers_iqr.sum())
# Out:
# outliers detect using outliers
# size           839
# total_sqft    1164
# bath          1032
# balcony          0
# price         1214
# dtype: int64

# %%
#filter out the rows with any outliers
df2=df2[~(outliers_iqr.any(axis=1))]
print("data after removing outliers (IQR):")
print(df2)
# Out:
# data after removing outliers (IQR):
#                   area_type   availability                  location  size  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II     2
# 2            Built-up  Area  Ready To Move               Uttarahalli     3
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli     3
# 4      Super built-up  Area  Ready To Move                  Kothanur     2
# 5      Super built-up  Area  Ready To Move                Whitefield     2
# ...                     ...            ...                       ...   ...
# 13309  Super built-up  Area  Ready To Move              Yeshwanthpur     3
# 13310  Super built-up  Area  Ready To Move              Rachenahalli     2
# 13312  Super built-up  Area  Ready To Move                 Bellandur     2
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout     3
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar     2
#
#        total_sqft  bath  balcony   price
# 0          1056.0     2        1   39.07
# 2          1440.0     2        3   62.00
# 3          1521.0     3        1   95.00
# 4          1200.0     2        1   51.00
# 5          1170.0     2        1   38.00
# ...           ...   ...      ...     ...
# 13309      1675.0     3        1   92.13
# 13310      1050.0     2        2   52.71
# 13312      1262.0     2        2   47.00
# 13314      1715.0     3        3  112.00
# 13317      1141.0     2        1   60.00
#
# [10574 rows x 8 columns]

# %%
#Define a function  to calculate IQR outliers
def detect_outliers(column):
  q1=column.quantile(0.25)
  q3=column.quantile(0.75)
  iqr=q3-q1
  lower_bound=q1-1.5*iqr
  upper_bound=q3+1.5*iqr
  return(column < lower_bound ) | (column > upper_bound)

# %%
#apply the function to numeric columns
outliers_iqr=df2[['size','total_sqft','bath','balcony','price']].apply(detect_outliers)

# %%
#View outliers
print('outliers detect using outliers')
print(outliers_iqr.sum())
# Out:
# outliers detect using outliers
# size            0
# total_sqft    374
# bath            0
# balcony         0
# price         531
# dtype: int64

# %%
import numpy as np
from scipy.stats import zscore

# %%
# Compute Z-scores
z_scores = df2[[ 'size', 'total_sqft', 'bath',
       'balcony', 'price']].apply(zscore)

# %%
# Define threshold
threshold = 3

# %%
# Identify outliers
outliers_z = (z_scores.abs() > threshold)

# %%
# View outliers
print("Outliers detected using Z-Score:")
print(outliers_z.sum())  # Count of outliers per column
# Out:
# Outliers detected using Z-Score:
# size            0
# total_sqft     60
# bath            0
# balcony         0
# price         174
# dtype: int64

# %% [markdown]
# #feature engineering

# %%
df3 =df2.copy()
df3
# Out:
#                   area_type   availability                  location  size  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II     2
# 2            Built-up  Area  Ready To Move               Uttarahalli     3
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli     3
# 4      Super built-up  Area  Ready To Move                  Kothanur     2
# 5      Super built-up  Area  Ready To Move                Whitefield     2
# ...                     ...            ...                       ...   ...
# 13309  Super built-up  Area  Ready To Move              Yeshwanthpur     3
# 13310  Super built-up  Area  Ready To Move              Rachenahalli     2
# 13312  Super built-up  Area  Ready To Move                 Bellandur     2
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout     3
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar     2
#
#        total_sqft  bath  balcony   price
# 0          1056.0     2        1   39.07
# 2          1440.0     2        3   62.00
# 3          1521.0     3        1   95.00
# 4          1200.0     2        1   51.00
# 5          1170.0     2        1   38.00
# ...           ...   ...      ...     ...
# 13309      1675.0     3        1   92.13
# 13310      1050.0     2        2   52.71
# 13312      1262.0     2        2   47.00
# 13314      1715.0     3        3  112.00
# 13317      1141.0     2        1   60.00
#
# [10574 rows x 8 columns]

# %%
df3['availability'].unique()
# Out:
# array(['19-Dec', 'Ready To Move', '18-Feb', '18-Nov', '18-May', '20-Dec',
#        '17-Oct', '21-Dec', '19-Sep', '20-Sep', '18-Mar', '18-Apr',
#        '20-Aug', '19-Mar', '17-Sep', '18-Dec', '17-Aug', '19-Apr',
#        '18-Jun', '22-Dec', '22-Jan', '18-Aug', '19-Jan', '17-Jul',
#        '18-Jul', '21-Jun', '19-Aug', '18-Sep', '17-Jun', '18-Oct',
#        '21-May', '18-Jan', '20-Mar', '17-Dec', '16-Mar', '19-Jun',
#        '22-Jun', '17-May', '19-Jul', '21-Feb', 'Immediate Possession',
#        '19-May', '20-Oct', '20-Jun', '19-Feb', '21-Oct', '21-Jan',
#        '17-Mar', '17-Nov', '17-Apr', '19-Oct', '21-Jul', '21-Nov',
#        '21-Mar', '16-Dec', '22-Mar', '20-Jan', '21-Sep', '21-Aug',
#        '22-May', '14-Nov', '19-Nov', '15-Nov', '16-Jul', '15-Jun',
#        '20-May', '20-Nov', '20-Jul', '16-Sep', '15-Oct', '20-Feb',
#        '15-Dec', '16-Oct', '22-Nov', '15-Aug', '17-Jan', '16-Nov',
#        '20-Apr', '16-Jan', '17-Feb', '14-Jul'], dtype=object)

# %%
df3['availability_status'] = np.where(df3['availability'] == 'Ready To Move', 'Immediatly available', 'Available Later')
df3.drop(columns=['availability'], inplace=True)

# %%
df3['availability_status'].value_counts()
# Out:
# availability_status
# Immediatly available    8251
# Available Later         2323
# Name: count, dtype: int64

# %% [markdown]
# # feature transformation

# %%
skewness = df3[['size','total_sqft','bath','balcony','price']].skew()
print(skewness)
# Out:
# size          0.127235
# total_sqft    0.488863
# bath          0.572639
# balcony       0.101919
# price         1.311835
# dtype: float64

# %%
skewness = df1[['size','total_sqft','bath','balcony','price']].skew()
print(skewness)
# Out:
# size           4.798262
# total_sqft    15.075517
# bath           4.210551
# balcony        0.094079
# price          7.945364
# dtype: float64

# %%
for col in['size','total_sqft','bath','balcony','price']:
  sns.histplot(df3[col],kde=True)
  plt.title(f'distribution of{col}')
  plt.show()
  #price is target

# %%
skewness = df3[['size','total_sqft','bath','balcony','price']].skew()
print(skewness)


import seaborn as sns
import matplotlib.pyplot as plt

for col in ['size','total_sqft','bath','balcony','price']:
  sns.histplot(df3[col], kde=True)
  plt.title(f"Distribution of {col}")
  plt.show()



# Log transformation for 'price'
df3['price_log'] = np.log1p(df3['price'])

# Square root transformation for 'price'
df3['price_sqrt'] = np.sqrt(df3['price'])

# Display the results
print(df3[['price', 'price_log', 'price_sqrt']])
# Out:
# size          0.127235
# total_sqft    0.488863
# bath          0.572639
# balcony       0.101919
# price         1.311835
# dtype: float64
#         price  price_log  price_sqrt
# 0       39.07   3.690628    6.250600
# 2       62.00   4.143135    7.874008
# 3       95.00   4.564348    9.746794
# 4       51.00   3.951244    7.141428
# 5       38.00   3.663562    6.164414
# ...       ...        ...         ...
# 13309   92.13   4.533996    9.598437
# 13310   52.71   3.983599    7.260165
# 13312   47.00   3.871201    6.855655
# 13314  112.00   4.727388   10.583005
# 13317   60.00   4.110874    7.745967
#
# [10574 rows x 3 columns]

# %%
skewness= df3[['price','price_sqrt','price_sqrt']].skew()
print(skewness)
# Out:
# price         1.311835
# price_sqrt    0.671824
# price_sqrt    0.671824
# dtype: float64

# %%
df3.drop(columns=['price_sqrt','price'],inplace=True)

# %% [markdown]
# # **Encoding**

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10574 entries, 0 to 13317
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   area_type            10574 non-null  object
#  1   location             10574 non-null  object
#  2   size                 10574 non-null  int64
#  3   total_sqft           10574 non-null  float64
#  4   bath                 10574 non-null  int64
#  5   balcony              10574 non-null  int64
#  6   availability_status  10574 non-null  object
#  7   price_log            10574 non-null  float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 743.5+ KB

# %%
df3['location'].unique()
# Out:
# array(['Electronic City Phase II', 'Uttarahalli', 'Lingadheeranahalli',
#        ..., 'Tilak Nagar',
#        '12th cross srinivas nagar banshankari 3rd stage', 'Abshot Layout'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df3['location']=le.fit_transform(df3['location'])
df3['location'].dtypes
# Out:
# dtype('int64')

# %%
df3['location']
# Out:
# 0         354
# 2        1008
# 3         651
# 4         617
# 5        1069
#          ...
# 13309    1082
# 13310     819
# 13312     193
# 13314     402
# 13317     826
# Name: location, Length: 10574, dtype: int64

# %%
df3.area_type
# Out:
# 0        Super built-up  Area
# 2              Built-up  Area
# 3        Super built-up  Area
# 4        Super built-up  Area
# 5        Super built-up  Area
#                  ...
# 13309    Super built-up  Area
# 13310    Super built-up  Area
# 13312    Super built-up  Area
# 13314    Super built-up  Area
# 13317          Built-up  Area
# Name: area_type, Length: 10574, dtype: object

# %%
df3['area_type']=df3['area_type'].map({"carpet_area":0,"plot_area":1,"super built-up Area":3,"built_up_area":2})

# %%
df3

# %%
df3['availability_status'].unique()

# %% [markdown]
# #one hot encoding

# %%
one_hot_encoded=pd.get_dummies(df3['availability_status'],prefix='onehot',dtype=int)
df3=pd.concat([df3,one_hot_encoded],axis=1)
df3
# Out:
#                   area_type  location  size  total_sqft  bath  balcony  \
# 0      Super built-up  Area       354     2      1056.0     2        1
# 2            Built-up  Area      1008     3      1440.0     2        3
# 3      Super built-up  Area       651     3      1521.0     3        1
# 4      Super built-up  Area       617     2      1200.0     2        1
# 5      Super built-up  Area      1069     2      1170.0     2        1
# ...                     ...       ...   ...         ...   ...      ...
# 13309  Super built-up  Area      1082     3      1675.0     3        1
# 13310  Super built-up  Area       819     2      1050.0     2        2
# 13312  Super built-up  Area       193     2      1262.0     2        2
# 13314  Super built-up  Area       402     3      1715.0     3        3
# 13317        Built-up  Area       826     2      1141.0     2        1
#
#         availability_status  price_log  onehot_Available Later  \
# 0           Available Later   3.690628                       1
# 2      Immediatly available   4.143135                       0
# 3      Immediatly available   4.564348                       0
# 4      Immediatly available   3.951244                       0
# 5      Immediatly available   3.663562                       0
# ...                     ...        ...                     ...
# 13309  Immediatly available   4.533996                       0
# 13310  Immediatly available   3.983599                       0
# 13312  Immediatly available   3.871201                       0
# 13314  Immediatly available   4.727388                       0
# 13317  Immediatly available   4.110874                       0
#
#        onehot_Immediatly available
# 0                                0
# 2                                1
# 3                                1
# 4                                1
# 5                                1
# ...                            ...
# 13309                            1
# 13310                            1
# 13312                            1
# 13314                            1
# 13317                            1
#
# [10574 rows x 10 columns]

# %%
df3.drop(columns=["availability_status"],inplace=True)

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df3.corr(),annot=True,cmap='coolwarm')
plt.show()

# %%
df3.drop(columns=['location','onehot_Available Later','onehot_Immediatly available'],inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-210-aefdfc4f4e71> in <cell line: 0>()
# ----> 1 df3.drop(columns=['location','onehot_Available Later','onehot_Immediatly available'],inplace=True)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4828                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4829             else:
# -> 4830                 new_axis = axis.drop(labels, errors=errors)
#    4831             indexer = axis.get_indexer(new_axis)
#    4832
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    7068         if mask.any():
#    7069             if errors != "ignore":
# -> 7070                 raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071             indexer = indexer[~mask]
#    7072         return self.delete(indexer)
#
# KeyError: "['location', 'onehot_Available Later', 'onehot_Immediatly available'] not found in axis"

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10574 entries, 0 to 13317
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   area_type   0 non-null      float64
#  1   size        10574 non-null  int64
#  2   total_sqft  10574 non-null  float64
#  3   bath        10574 non-null  int64
#  4   balcony     10574 non-null  int64
#  5   price_log   10574 non-null  float64
# dtypes: float64(3), int64(3)
# memory usage: 578.3 KB

# %%
from sklearn.preprocessing import MinMaxScaler

# MINMAX SCALLING
minmax_scaler = MinMaxScaler()

df_minmax_scaled = minmax_scaler.fit_transform(df3)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_array_api.py:769: RuntimeWarning: All-NaN slice encountered
#   return xp.asarray(numpy.nanmin(X, axis=axis))
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_array_api.py:786: RuntimeWarning: All-NaN slice encountered
#   return xp.asarray(numpy.nanmax(X, axis=axis))

# %%
df_minmax_scaled
# Out:
# array([[       nan, 0.33333333, 0.34756361, 0.33333333, 0.33333333,
#         0.46018936],
#        [       nan, 0.66666667, 0.51315222, 0.33333333, 1.        ,
#         0.59962846],
#        [       nan, 0.66666667, 0.54808107, 0.66666667, 0.33333333,
#         0.72942457],
#        ...,
#        [       nan, 0.33333333, 0.436395  , 0.33333333, 0.66666667,
#         0.51583261],
#        [       nan, 0.66666667, 0.63173782, 0.66666667, 1.        ,
#         0.77966492],
#        [       nan, 0.33333333, 0.38421734, 0.33333333, 0.33333333,
#         0.58968733]])

# %%
df_minmax_scaled = pd.DataFrame(df_minmax_scaled, columns=df3.columns)
df_minmax_scaled
# Out:
#        area_type      size  total_sqft      bath   balcony  price_log
# 0            NaN  0.333333    0.347564  0.333333  0.333333   0.460189
# 1            NaN  0.666667    0.513152  0.333333  1.000000   0.599628
# 2            NaN  0.666667    0.548081  0.666667  0.333333   0.729425
# 3            NaN  0.333333    0.409659  0.333333  0.333333   0.540498
# 4            NaN  0.333333    0.396723  0.333333  0.333333   0.451849
# ...          ...       ...         ...       ...       ...        ...
# 10569        NaN  0.666667    0.614489  0.666667  0.333333   0.720072
# 10570        NaN  0.333333    0.344976  0.333333  0.666667   0.550468
# 10571        NaN  0.333333    0.436395  0.333333  0.666667   0.515833
# 10572        NaN  0.666667    0.631738  0.666667  1.000000   0.779665
# 10573        NaN  0.333333    0.384217  0.333333  0.333333   0.589687
#
# [10574 rows x 6 columns]

# %%
# create subplot
plt.figure(figsize=(12,10))

# Original and scaledd data histograms for each feature
plt.subplot(5, 2, 1)
sns.histplot(df3['size'], kde=True)
plt.title('Orginal: size')

plt.subplot(5, 2, 2)
sns.histplot(df_minmax_scaled['size'], kde=True)
plt.title('Scaled: size')

plt.subplot(5, 2, 3)
sns.histplot(df3['total_sqft'], kde=True)
plt.title('Orginal: total_sqft')

plt.subplot(5, 2, 4)
sns.histplot(df_minmax_scaled['total_sqft'], kde=True)
plt.title('Scaled: total_sqft')

plt.subplot(5, 2, 5)
sns.histplot(df3['balcony'], kde=True)
plt.title('Orginal: balcony')

plt.subplot(5, 2, 6)
sns.histplot(df_minmax_scaled['balcony'], kde=True)
plt.title('Scaled: balcony')

plt.tight_layout()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create subplots
plt.figure(figsize=(12, 10))

# Original and scaled data histograms for each feature
plt.subplot(5, 2, 1)
sns.histplot(df3['size'], kde=True)
plt.title('Original: size')

plt.subplot(5, 2, 2)
sns.histplot(df_minmax_scaled['size'], kde=True)
plt.title('Scaled: size')

plt.subplot(5, 2, 3)
sns.histplot(df3['total_sqft'], kde=True)
plt.title('Original: total_sqft')

plt.subplot(5, 2, 4)
sns.histplot(df_minmax_scaled['total_sqft'], kde=True)
plt.title('Scaled: total_sqft')

plt.subplot(5, 2, 5)
sns.histplot(df3['bath'], kde=True)
plt.title('Original: bath')

plt.subplot(5, 2, 6)
sns.histplot(df_minmax_scaled['bath'], kde=True)
plt.title('Scaled: bath')

plt.subplot(5, 2, 7)
sns.histplot(df3['balcony'], kde=True)
plt.title('Original: balcony')

plt.subplot(5, 2, 8)
sns.histplot(df_minmax_scaled['balcony'], kde=True)
plt.title('Scaled: balcony')

plt.subplot(5, 2, 9)
sns.histplot(df3['price_log'], kde=True)
plt.title('Original: price_log')

plt.subplot(5, 2, 10)
sns.histplot(df_minmax_scaled['price_log'], kde=True)
plt.title('Scaled: price_log')


plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
#standard scaler
standard_scaler=StandardScaler()
df_standard_scaled=standard_scaler.fit_transform(df3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-93913767dcc2> in <cell line: 0>()
#       2 #standard scaler
#       3 standard_scaler=StandardScaler()
# ----> 4 df_standard_scaled=standard_scaler.fit_transform(df3)
#
# NameError: name 'df3' is not defined

# %%
df_standard_scaled= pd.DataFrame(df_standard_scaled,columns=df3.columns)
df_standard_scaled

# %%
# create subplot
plt.figure(figsize=(12,10))

# Original and scaledd data histograms for each feature
plt.subplot(5, 2, 1)
sns.histplot(df3['size'], kde=True)
plt.title('Orginal: size')

plt.subplot(5, 2, 2)
sns.histplot(df_standard_scaled['size'], kde=True)
plt.title('Scaled: size')

plt.subplot(5, 2, 3)
sns.histplot(df3['total_sqft'], kde=True)
plt.title('Orginal: total_sqft')

plt.subplot(5, 2, 4)
sns.histplot(df_standard_scaled['total_sqft'], kde=True)
plt.title('Scaled: total_sqft')

plt.subplot(5, 2, 5)
sns.histplot(df3['balcony'], kde=True)
plt.title('Orginal: balcony')

plt.subplot(5, 2, 6)
sns.histplot(df_standard_scaled['balcony'], kde=True)
plt.title('Scaled: balcony')

plt.tight_layout()

# %%
df3.info()

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df_standard_scaled.corr(),annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# #**dimentionality** **reduction**
